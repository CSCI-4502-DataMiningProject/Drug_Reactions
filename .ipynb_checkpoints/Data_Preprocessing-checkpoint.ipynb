# %% [markdown]
# # Predicting Adverse Drug Reactions Based on Patient Demographics
#
# ### Anthony Olvera
# ### CSCI 4502 Data Minning Project Fall 2018
# ### Data Integration, Cleaning and Preprocessing

# %% [markdown]
# The raw data we will process here was downloaded at https://open.fda.gov/tools/downloads/ and inflated to a total of 788 json files. The files take a total of roughley 203 GB of space which will be best managed in a relational database as opposed to files. My goal is to first load the data into a dataframe, filter and reduce by dropping irrelevent attributes follwed by dropping all relevent entries with one or more null values. I will then proceed to preprocess the data by eliminating outliers and normalizing where appropriate. after all cleaning and preprocessing I will store the data as a single postgre sql relational database where it can be accessed in the future for all remaining work on the project.

# %%
# Import all nessasary utilities
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
import json

# %%
# test reading a json file and output result
data = json.load(open('G:\drug-event-0001-of-0004.json'))
patient_info = json_normalize(data['results'])
df = pd.DataFrame(patient_info)

# %%
# what are the attributes
list(df)
# Out:
# ['companynumb',
#  'fulfillexpeditecriteria',
#  'patient.drug',
#  'patient.patientdeath.patientdeathdate',
#  'patient.patientdeath.patientdeathdateformat',
#  'patient.patientonsetage',
#  'patient.patientonsetageunit',
#  'patient.patientsex',
#  'patient.patientweight',
#  'patient.reaction',
#  'primarysource',
#  'primarysource.qualification',
#  'primarysource.reportercountry',
#  'receiptdate',
#  'receiptdateformat',
#  'receivedate',
#  'receivedateformat',
#  'receiver',
#  'safetyreportid',
#  'sender.senderorganization',
#  'serious',
#  'seriousnesscongenitalanomali',
#  'seriousnessdeath',
#  'seriousnessdisabling',
#  'seriousnesshospitalization',
#  'seriousnesslifethreatening',
#  'seriousnessother',
#  'transmissiondate',
#  'transmissiondateformat']

# %%
# Most intersting attibutes include all patient related attributes, primary source, seriousness measures
# and transmission information, all other attributes will be droped.
df = df.drop(columns = ['companynumb', 'fulfillexpeditecriteria', 'primarysource','receiptdate',
                        'receiptdateformat', 'receivedateformat', 'receiver',
                       'safetyreportid','sender.senderorganization','transmissiondateformat',
                       'patient.patientdeath.patientdeathdateformat','patient.patientonsetageunit'])
df.head()
# Out:
#                                         patient.drug  \
# 0  [{'drugstartdateformat': '102', 'medicinalprod...
# 1  [{'drugstartdateformat': '102', 'medicinalprod...
# 2  [{'drugstartdateformat': '102', 'medicinalprod...
# 3  [{'drugstartdateformat': '102', 'medicinalprod...
# 4  [{'medicinalproduct': 'IRESSA', 'drugindicatio...
#
#   patient.patientdeath.patientdeathdate patient.patientonsetage  \
# 0                                   NaN                     NaN
# 1                                   NaN                     NaN
# 2                              20040322                      66
# 3                                   NaN                      61
# 4                                   NaN                      77
#
#   patient.patientsex patient.patientweight  \
# 0                NaN                   NaN
# 1                  2                   NaN
# 2                  1               78.9259
# 3                  2               49.4421
# 4                  2                   NaN
#
#                                     patient.reaction  \
# 0                    [{'reactionmeddrapt': 'DEATH'}]
# 1  [{'reactionmeddrapt': 'ABORTION SPONTANEOUS'},...
# 2  [{'reactionmeddrapt': 'INTERSTITIAL LUNG DISEA...
# 3  [{'reactionmeddrapt': 'ABDOMINAL DISTENSION'},...
# 4                  [{'reactionmeddrapt': 'ANAEMIA'}]
#
#   primarysource.qualification primarysource.reportercountry receivedate  \
# 0                         NaN                       AUSTRIA    20101115
# 1                           3                UNITED KINGDOM    20090803
# 2                           1                 UNITED STATES    20061213
# 3                         NaN                 UNITED STATES    20061213
# 4                           1                 UNITED STATES    20061213
#
#   serious seriousnesscongenitalanomali seriousnessdeath seriousnessdisabling  \
# 0       1                          NaN                1                  NaN
# 1       1                          NaN              NaN                  NaN
# 2       1                          NaN                1                  NaN
# 3       1                          NaN              NaN                  NaN
# 4       1                          NaN              NaN                  NaN
#
#   seriousnesshospitalization seriousnesslifethreatening seriousnessother  \
# 0                        NaN                        NaN              NaN
# 1                        NaN                        NaN                1
# 2                        NaN                        NaN              NaN
# 3                        NaN                        NaN                1
# 4                        NaN                        NaN                1
#
#   transmissiondate
# 0         20110411
# 1         20100115
# 2         20070707
# 3         20070707
# 4         20070707

# %%
# it can be seen that patient.drug and patient.reaction need to be expanded
# create two new data frames for each attribute filter/reduce then merge with original 

# create a new reaction dataframe
data = []
for row in range(len(df['patient.reaction'])):
    reactions = []
    for list_index in range(len(df['patient.reaction'][row])):
        reactions.append(df['patient.reaction'][row][list_index]['reactionmeddrapt'])
    data.append(reactions)
reaction = pd.DataFrame(data)

# create a new drug dataframe 
data = []
for row in range(len(df['patient.drug'])):
    drugs = []
    for list_index in range(len(df['patient.drug'][row])):
        drugs.append(df['patient.drug'][row][list_index]['medicinalproduct'])
    data.append(drugs)
drug = pd.DataFrame(data)

# give columns appropriate names  
for column in reaction.columns:
    reaction = reaction.rename(columns = {column : 'Reaction_' + str(column)})
    
for column in drug.columns:
    drug = drug.rename(columns = {column : 'Drug_' + str(column)})

# %%
# Now drop the nested columns and merge with new dataframes
df = df.drop(columns = ['patient.drug','patient.reaction'])

patient_info = pd.concat([df, drug, reaction], axis=1, join='inner')

# some more column filtering
patient_info = patient_info[['patient.patientonsetage',	'patient.patientsex','patient.patientweight', 
                             'primarysource.reportercountry','serious','transmissiondate', 
                             'receivedate','Drug_0', 'Reaction_0', 'Reaction_1', 'Reaction_2']]

# %%
# check column datatypes
patient_info.dtypes
# Out:
# patient.patientonsetage          object
# patient.patientsex               object
# patient.patientweight            object
# primarysource.reportercountry    object
# serious                          object
# transmissiondate                 object
# receivedate                      object
# Drug_0                           object
# Reaction_0                       object
# Reaction_1                       object
# Reaction_2                       object
# dtype: object

# %%
# convert columns to numeric data
patient_info['patient.patientonsetage'] = pd.to_numeric(df['patient.patientonsetage'])
patient_info['patient.patientweight'] = pd.to_numeric(df['patient.patientweight'])

# Now eliminate outliers on age and weight
age_q1 = patient_info['patient.patientonsetage'].quantile(0.25)
age_q3 = patient_info['patient.patientonsetage'].quantile(0.75)
age_IQR = age_q3 - age_q1
weight_q1 = patient_info['patient.patientweight'].quantile(0.25)
weight_q3 = patient_info['patient.patientweight'].quantile(0.75)
weight_IQR = weight_q3 - weight_q1
age_upperbound = age_q3 + 1.5*age_IQR
age_lowerbound = age_q1 - 1.5*age_IQR
weight_upperbound = weight_q3 + 1.5*weight_IQR
weight_lowerbound = weight_q3 - 1.5*weight_IQR
patient_info = patient_info.drop(
    patient_info[patient_info['patient.patientonsetage'] < age_lowerbound].index)
patient_info = patient_info.drop(
    patient_info[patient_info['patient.patientonsetage'] > age_upperbound].index)
patient_info = patient_info.drop(
    patient_info[patient_info['patient.patientweight'] < weight_lowerbound].index)
patient_info = patient_info.drop(
    patient_info[patient_info['patient.patientweight'] > weight_upperbound].index)

# %%
# drop all rows with null patient demographic info 
patient_info = patient_info.dropna(subset=['patient.patientonsetage', 'patient.patientsex',
                                                                            'patient.patientweight',])
# make sure we will still have millions of data points  
patient_info.count()
# Out:
# patient.patientonsetage          2464
# patient.patientsex               2464
# patient.patientweight            2464
# primarysource.reportercountry      36
# serious                          2464
# transmissiondate                 2464
# receivedate                      2464
# Drug_0                           2464
# Reaction_0                       2464
# Reaction_1                       1743
# Reaction_2                       1259
# dtype: int64

# %%
# Preview of the data
patient_info
# Out:
#        patient.patientonsetage patient.patientsex  patient.patientweight  \
# 2                         66.0                  1                78.9259
# 3                         61.0                  2                49.4421
# 5                         67.0                  2                74.8435
# 14                        56.0                  1                75.7507
# 17                        66.0                  1                72.5755
# 35                        31.0                  2                77.1000
# 37                        45.0                  2               107.0489
# 41                        66.0                  1                82.6000
# 46                        31.0                  2                61.2356
# 47                        33.0                  1                75.0000
# 55                        58.0                  2                90.7194
# 88                        71.0                  1                69.0000
# 89                        76.0                  2                61.0000
# 93                        39.0                  1                89.0000
# 96                        34.0                  2                59.0000
# 100                       67.0                  1                50.8029
# 103                       83.0                  2                53.9780
# 104                       59.0                  2                49.8957
# 107                       48.0                  2                93.0000
# 114                       77.0                  2                58.9676
# 118                       56.0                  2                81.6475
# 125                       70.0                  1                79.3795
# 132                       25.0                  1                52.0000
# 136                       56.0                  1                77.0000
# 137                       43.0                  2                50.6000
# 145                       58.0                  1               113.0000
# 152                       42.0                  1                90.7194
# 155                       78.0                  2                67.5860
# 156                       39.0                  1                90.7194
# 158                       79.0                  2                50.8029
# ...                        ...                ...                    ...
# 11850                     74.0                  2                61.2356
# 11852                     65.0                  1                80.0000
# 11854                     55.0                  1                81.1939
# 11859                     46.0                  2                54.4316
# 11866                     78.0                  1                63.5036
# 11871                     76.0                  1                56.0000
# 11874                     68.0                  2                75.0000
# 11875                     74.0                  2                51.0000
# 11883                     56.0                  1               101.1000
# 11889                     29.0                  1                81.4000
# 11895                     12.0                  1                59.0000
# 11899                     62.0                  1                87.7000
# 11903                     17.0                  1                68.0000
# 11910                     30.0                  2                50.0000
# 11923                     82.0                  2                59.1000
# 11925                     49.0                  2                92.9874
# 11926                     45.0                  1                64.0000
# 11929                     65.0                  2                64.8644
# 11937                     35.0                  2                61.2356
# 11940                     37.0                  1                69.9000
# 11942                     25.0                  2                56.6996
# 11944                     64.0                  2                70.3075
# 11959                     48.0                  1                80.0000
# 11964                     61.0                  1                84.6000
# 11968                     69.0                  2                56.0000
# 11971                     54.0                  2               104.0000
# 11975                     69.0                  2                68.0000
# 11977                     40.0                  1                99.7913
# 11995                     33.0                  2                99.9700
# 11996                     62.0                  2                79.4000
#
#       primarysource.reportercountry serious transmissiondate receivedate  \
# 2                     UNITED STATES       1         20070707    20061213
# 3                     UNITED STATES       1         20070707    20061213
# 5                     UNITED STATES       1         20070707    20061213
# 14                    UNITED STATES       1         20070707    20061213
# 17                    UNITED STATES       2         20070707    20061212
# 35                              NaN       2         20050107    20040429
# 37                              NaN       2         20050107    20040427
# 41                              NaN       1         20051028    20050628
# 46                              NaN       1         20041129    20040326
# 47                              NaN       2         20041129    20040202
# 55                    UNITED STATES       2         20070707    20061213
# 88                              NaN       1         20050727    20050218
# 89                              NaN       2         20050727    20050224
# 93                              NaN       2         20050328    20041022
# 96                              NaN       2         20050211    20040928
# 100                   UNITED STATES       1         20070707    20061213
# 103                   UNITED STATES       1         20070707    20061213
# 104                   UNITED STATES       2         20070707    20061213
# 107                             NaN       1         20050107    20040405
# 114                   UNITED STATES       1         20070707    20061213
# 118                   UNITED STATES       1         20070707    20061213
# 125                   UNITED STATES       1         20070707    20061213
# 132                             NaN       2         20050107    20040409
# 136                             NaN       1         20050107    20040415
# 137                             NaN       1         20050107    20040511
# 145                             NaN       2         20050727    20050224
# 152                   UNITED STATES       2         20070707    20061213
# 155                   UNITED STATES       1         20070707    20061213
# 156                   UNITED STATES       1         20070707    20061213
# 158                             NaN       1         20050727    20050201
# ...                             ...     ...              ...         ...
# 11850                           NaN       1         20041129    20040225
# 11852                           NaN       1         20041129    20040225
# 11854                           NaN       2         20041129    20040303
# 11859                           NaN       2         20041129    20040227
# 11866                           NaN       2         20050107    20040415
# 11871                           NaN       1         20041129    20040319
# 11874                           NaN       1         20041129    20040331
# 11875                           NaN       1         20041129    20040331
# 11883                           NaN       1         20050211    20040728
# 11889                           NaN       2         20050211    20040809
# 11895                           NaN       1         20050107    20040526
# 11899                           NaN       1         20050107    20040407
# 11903                           NaN       2         20050211    20040728
# 11910                           NaN       1         20041129    20040317
# 11923                           NaN       2         20050107    20040630
# 11925                           NaN       2         20050107    20040610
# 11926                           NaN       1         20050107    20040405
# 11929                           NaN       1         20050107    20040408
# 11937                           NaN       1         20041129    20040223
# 11940                           NaN       1         20041129    20040202
# 11942                           NaN       2         20041129    20040319
# 11944                           NaN       1         20041129    20040305
# 11959                           NaN       1         20041129    20040319
# 11964                           NaN       2         20050107    20040601
# 11968                           NaN       2         20050107    20040426
# 11971                           NaN       1         20041129    20040218
# 11975                           NaN       1         20041129    20040212
# 11977                           NaN       1         20041129    20040212
# 11995                           NaN       2         20050107    20040429
# 11996                           NaN       1         20050107    20040503
#
#                                 Drug_0                          Reaction_0  \
# 2                               IRESSA           INTERSTITIAL LUNG DISEASE
# 3                               IRESSA                ABDOMINAL DISTENSION
# 5                               IRESSA                              CHILLS
# 14                              IRESSA           INTERSTITIAL LUNG DISEASE
# 17                             CASODEX         BLOOD CHOLESTEROL INCREASED
# 35                            NUVARING                      DEVICE FAILURE
# 37                               EMEND                    CHEST DISCOMFORT
# 41                           VISIPAQUE          BLOOD CREATININE INCREASED
# 46                           PHENERGAN                      CAUSTIC INJURY
# 47                             CRESTOR                ERECTILE DYSFUNCTION
# 55                           TAMOXIFEN                  ENDOMETRIAL CANCER
# 88                         CARBOPLATIN                    HYPERSENSITIVITY
# 89                 EXCEDRIN (MIGRAINE)                              NAUSEA
# 93                              BUSPAR                           AGITATION
# 96                          KENALOG-40              INJECTION SITE ATROPHY
# 100                             IRESSA            PLATELET COUNT DECREASED
# 103                             IRESSA                           DIARRHOEA
# 104                          TAMOXIFEN                  DISEASE RECURRENCE
# 107                         PEG-INTRON                  AFFECTIVE DISORDER
# 114                           SEROQUEL              INTESTINAL OBSTRUCTION
# 118                             IRESSA                                ACNE
# 125                             IRESSA                        HAEMATEMESIS
# 132                        SEVOFLURANE                    DRUG INTERACTION
# 136                          HUMULIN N           BLOOD GLUCOSE FLUCTUATION
# 137                              ZYBAN  ALANINE AMINOTRANSFERASE INCREASED
# 145                EXCEDRIN (MIGRAINE)                    DRUG INEFFECTIVE
# 152                           SEROQUEL                  TARDIVE DYSKINESIA
# 155                             IRESSA                            ALOPECIA
# 156                           SEROQUEL           CONSCIOUSNESS FLUCTUATING
# 158                             AVELOX               ANAPHYLACTIC REACTION
# ...                                ...                                 ...
# 11850                          VASOTEC              DERMATITIS EXFOLIATIVE
# 11852                           PERMAX               MYOCARDIAL INFARCTION
# 11854                       LOVASTATIN                  COLITIS ULCERATIVE
# 11859                        FABRAZYME                          ECCHYMOSIS
# 11866                         CLARINEX                         POLLAKIURIA
# 11871                    DONEPEZIL HCL                         ATELECTASIS
# 11874                    HUMULIN 70/30                            CATARACT
# 11875                           FORTEO             BLOOD CALCIUM INCREASED
# 11883                          RITUXAN                      SERUM SICKNESS
# 11889                            PAXIL                           BACK PAIN
# 11895                          ZYPREXA                  ABNORMAL BEHAVIOUR
# 11899  GM-CSF (SARGRAMOSTIM) INJECTION              BLOOD CULTURE POSITIVE
# 11903                        STRATTERA                          DEPRESSION
# 11910                          LAMISIL                ABORTION SPONTANEOUS
# 11923                       ADVAIR HFA                           DRY MOUTH
# 11925                         NATRECOR                 ACCIDENTAL EXPOSURE
# 11926                          GLEEVEC                                RASH
# 11929                         TRISENOX                            ANOREXIA
# 11937                         LEVAQUIN                          ARTHRALGIA
# 11940                         COMBIVIR                          CHEST PAIN
# 11942                       ORTHO EVRA                     ABNORMAL DREAMS
# 11944                          CRESTOR                           DRY MOUTH
# 11959                          TEMODAR            BLOOD PRESSURE DECREASED
# 11964                        FABRAZYME            BLOOD PRESSURE DECREASED
# 11968                       PARAPLATIN                    HYPERSENSITIVITY
# 11971                     APROVEL TABS                          CHEST PAIN
# 11975                           TEQUIN             BLOOD GLUCOSE INCREASED
# 11977                        PRAVACHOL               DIFFICULTY IN WALKING
# 11995                         NUVARING                         AMENORRHOEA
# 11996                       DIOVAN HCT             BLOOD PRESSURE ABNORMAL
#
#                                               Reaction_1  \
# 2                                                   None
# 3                               BLOOD PRESSURE DECREASED
# 5                                               DYSPNOEA
# 14                                                  None
# 17                                                  None
# 35                           MEDICAL DEVICE COMPLICATION
# 37                                              DYSPNOEA
# 41                                                  None
# 46                                         EXTRAVASATION
# 47                                                  None
# 55                                                  None
# 88                                                  None
# 89                                                  None
# 93                                                 ANGER
# 96                                                  None
# 100                                     WEIGHT DECREASED
# 103                                    PAIN IN EXTREMITY
# 104                                                 None
# 107                                           ARTHRALGIA
# 114                                                 None
# 118                                            DIARRHOEA
# 125                                          HAEMOPTYSIS
# 132                                        RENAL FAILURE
# 136                             BLOOD PRESSURE DECREASED
# 137                                           ARTHRALGIA
# 145                                                 None
# 152                                                 None
# 155                                            DIARRHOEA
# 156                                     MEDICATION ERROR
# 158                                     FEELING ABNORMAL
# ...                                                  ...
# 11850                                       EAR DISORDER
# 11852                            PERICARDIAL HAEMORRHAGE
# 11854                                               None
# 11859                                           INSOMNIA
# 11866                                               None
# 11871                                ATRIAL FIBRILLATION
# 11874                                    EYE HAEMORRHAGE
# 11875                                  CONFUSIONAL STATE
# 11883                                               None
# 11889                           HEPATIC ENZYME INCREASED
# 11895                                             ATAXIA
# 11899                      CATHETER RELATED COMPLICATION
# 11903                                 PERSONALITY CHANGE
# 11910  COMPLICATIONS OF MATERNAL EXPOSURE TO THERAPEU...
# 11923                                         HOARSENESS
# 11925                                          EPISTAXIS
# 11926                                   THROMBOCYTOPENIA
# 11929                                           ASTHENIA
# 11937                                            MYALGIA
# 11940                                           DYSPNOEA
# 11942                                     SLEEP DISORDER
# 11944                                           INSOMNIA
# 11959                                               None
# 11964                                         CHEST PAIN
# 11968                                               None
# 11971                              DRUG HYPERSENSITIVITY
# 11975                                               None
# 11977                           HEPATIC ENZYME INCREASED
# 11995                            URINARY TRACT INFECTION
# 11996                                  OEDEMA PERIPHERAL
#
#                                  Reaction_2
# 2                                      None
# 3                               CANDIDIASIS
# 5                                   FATIGUE
# 14                                     None
# 17                                     None
# 35                MEDICAL DEVICE DISCOMFORT
# 37                             PARAESTHESIA
# 41                                     None
# 46                        IATROGENIC INJURY
# 47                                     None
# 55                                     None
# 88                                     None
# 89                                     None
# 93                              MOOD SWINGS
# 96                                     None
# 100                                    None
# 103                          SKIN WRINKLING
# 104                                    None
# 107                                ASTHENIA
# 114                                    None
# 118                                DRY SKIN
# 125                                    None
# 132                                    None
# 136                            EYE DISORDER
# 137    ASPARTATE AMINOTRANSFERASE INCREASED
# 145                                    None
# 152                                    None
# 155                                    RASH
# 156                       MEMORY IMPAIRMENT
# 158                       RASH ERYTHEMATOUS
# ...                                     ...
# 11850                         HERPES ZOSTER
# 11852                                  None
# 11854                                  None
# 11859                      WEIGHT DECREASED
# 11866                                  None
# 11871                           BRADYCARDIA
# 11874                              GLAUCOMA
# 11875                            DYSGRAPHIA
# 11883                                  None
# 11889                                  None
# 11895                    COGNITIVE DISORDER
# 11899               CATHETER SITE INFECTION
# 11903                      WEIGHT DECREASED
# 11910        DRUG EXPOSURE DURING PREGNANCY
# 11923                     OEDEMA PERIPHERAL
# 11925                              HEADACHE
# 11926                             TRISOMY 8
# 11929                  BLOOD UREA INCREASED
# 11937                                  None
# 11940                               FATIGUE
# 11942                                  None
# 11944                      NASAL CONGESTION
# 11959                                  None
# 11964                                NAUSEA
# 11968                                  None
# 11971                      HYPERSENSITIVITY
# 11975                                  None
# 11977               MUSCLE ENZYME INCREASED
# 11995                                  None
# 11996                         RASH PRURITIC
#
# [2464 rows x 11 columns]

# %%
# check to see if patient demographic info is normally distributed or skewed
patient_info.hist(column = 'patient.patientonsetage',bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021DEA659828>]],
#       dtype=object)

# %%
patient_info.hist(column = 'patient.patientweight',bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021DE99E5438>]],
#       dtype=object)

# %%
# Weight looks slightley right skewed, make box plot for comparison
boxplot = patient_info.boxplot(column=['patient.patientonsetage', 'patient.patientweight'])
