# %% [markdown]
# # Predicting Adverse Drug Reactions Based on Patient Demographics
#
# ### Anthony Olvera
# ### CSCI 4502 Data Minning Project Fall 2018
# ### Data Integration, Cleaning, Preprocessing and Exploration

# %% [markdown]
# The raw data we will process here was downloaded at https://open.fda.gov/tools/downloads/ and inflated to a total of 788 json files. The files take a total of roughley 203 GB of space which will need to be shrunken to a rasonable size. My goal is to first load the data into a dataframe, filter and reduce by dropping irrelevent attributes follwed by dropping all relevent entries with one or more null values. I will then proceed to preprocess the data by eliminating outliers and normalizing where appropriate. After all cleaning and preprocessing I will explore the data in hopes of finding some interesting paterns and trends which will give us a start on our project. In the future I will reduce and merge all files into a single csv which will be used for all remaining work on the project.

# %%
# Import all nessasary utilities
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
import scipy.stats as stats
import json
import gc

# %%
# test reading a json file and output result
data = json.load(open('G:/drug-event-0001-of-0004.json'));
patient_info = json_normalize(data['results']);
df = pd.DataFrame(patient_info);

# %%
# what are the attributes
list(df)
# Out:
# ['companynumb',
#  'fulfillexpeditecriteria',
#  'patient.drug',
#  'patient.patientdeath.patientdeathdate',
#  'patient.patientdeath.patientdeathdateformat',
#  'patient.patientonsetage',
#  'patient.patientonsetageunit',
#  'patient.patientsex',
#  'patient.patientweight',
#  'patient.reaction',
#  'primarysource',
#  'primarysource.qualification',
#  'primarysource.reportercountry',
#  'receiptdate',
#  'receiptdateformat',
#  'receivedate',
#  'receivedateformat',
#  'receiver',
#  'safetyreportid',
#  'sender.senderorganization',
#  'serious',
#  'seriousnesscongenitalanomali',
#  'seriousnessdeath',
#  'seriousnessdisabling',
#  'seriousnesshospitalization',
#  'seriousnesslifethreatening',
#  'seriousnessother',
#  'transmissiondate',
#  'transmissiondateformat']

# %%
# Most intersting attibutes include all patient related attributes, primary source, seriousness measures
# and transmission information, all other attributes will be droped.
df = df.drop(columns = ['companynumb', 'fulfillexpeditecriteria', 'primarysource','receiptdate',
                        'receiptdateformat', 'receivedateformat', 'receiver',
                       'safetyreportid','sender.senderorganization','transmissiondateformat',
                       'patient.patientdeath.patientdeathdateformat','patient.patientonsetageunit'])
df
# Out:
#                                             patient.drug  \
# 0      [{'drugstartdateformat': '102', 'medicinalprod...
# 1      [{'drugstartdateformat': '102', 'medicinalprod...
# 2      [{'drugstartdateformat': '102', 'medicinalprod...
# 3      [{'drugstartdateformat': '102', 'medicinalprod...
# 4      [{'medicinalproduct': 'IRESSA', 'drugindicatio...
# 5      [{'drugstartdateformat': '102', 'medicinalprod...
# 6      [{'medicinalproduct': 'SEROQUEL', 'drugadminis...
# 7      [{'drugcharacterization': '1', 'drugauthorizat...
# 8      [{'medicinalproduct': 'IRESSA', 'drugindicatio...
# 9      [{'medicinalproduct': 'IRESSA', 'drugtreatment...
# 10     [{'drugstartdateformat': '102', 'medicinalprod...
# 11     [{'drugadministrationroute': '048', 'drugchara...
# 12     [{'drugstartdateformat': '102', 'medicinalprod...
# 13     [{'drugadministrationroute': '065', 'drugchara...
# 14     [{'drugstartdateformat': '102', 'medicinalprod...
# 15     [{'drugstartdateformat': '102', 'medicinalprod...
# 16     [{'drugcharacterization': '1', 'drugauthorizat...
# 17     [{'drugstartdateformat': '102', 'medicinalprod...
# 18     [{'drugcharacterization': '1', 'drugauthorizat...
# 19     [{'drugcharacterization': '1', 'drugauthorizat...
# 20     [{'drugcharacterization': '2', 'medicinalprodu...
# 21     [{'drugcharacterization': '1', 'drugauthorizat...
# 22     [{'drugstartdateformat': '102', 'medicinalprod...
# 23     [{'drugcharacterization': '1', 'drugauthorizat...
# 24     [{'medicinalproduct': 'TRACLEER', 'drugindicat...
# 25     [{'medicinalproduct': 'CELEBREX', 'drugindicat...
# 26     [{'drugcharacterization': '1', 'drugauthorizat...
# 27     [{'medicinalproduct': 'GLEEVEC', 'drugindicati...
# 28     [{'medicinalproduct': 'VALPROATE SODIUM', 'dru...
# 29     [{'drugstartdateformat': '102', 'medicinalprod...
# ...                                                  ...
# 11970  [{'medicinalproduct': 'LEVITRA', 'drugadminist...
# 11971  [{'drugstartdateformat': '102', 'medicinalprod...
# 11972  [{'drugcharacterization': '1', 'drugdosagetext...
# 11973  [{'drugadministrationroute': '048', 'drugchara...
# 11974  [{'drugstartdateformat': '102', 'medicinalprod...
# 11975  [{'drugstartdateformat': '102', 'medicinalprod...
# 11976  [{'drugstartdateformat': '102', 'medicinalprod...
# 11977  [{'drugcharacterization': '1', 'drugdosagetext...
# 11978  [{'drugcharacterization': '1', 'openfda': {'ma...
# 11979  [{'drugstartdateformat': '102', 'medicinalprod...
# 11980  [{'drugadministrationroute': '048', 'drugchara...
# 11981  [{'medicinalproduct': 'PAXIL', 'drugindication...
# 11982  [{'drugcharacterization': '1', 'openfda': {'ma...
# 11983  [{'drugadministrationroute': '048', 'drugchara...
# 11984  [{'medicinalproduct': 'PAXIL', 'drugindication...
# 11985  [{'drugadministrationroute': '048', 'drugchara...
# 11986  [{'medicinalproduct': 'PAXIL', 'drugindication...
# 11987  [{'drugadministrationroute': '048', 'drugchara...
# 11988  [{'drugstartdateformat': '102', 'medicinalprod...
# 11989  [{'drugstartdateformat': '102', 'medicinalprod...
# 11990  [{'drugstartdateformat': '102', 'medicinalprod...
# 11991  [{'drugstartdateformat': '102', 'medicinalprod...
# 11992  [{'drugstartdateformat': '102', 'medicinalprod...
# 11993  [{'drugstartdateformat': '102', 'medicinalprod...
# 11994  [{'drugstartdateformat': '102', 'medicinalprod...
# 11995  [{'drugstartdateformat': '102', 'medicinalprod...
# 11996  [{'drugstartdateformat': '102', 'medicinalprod...
# 11997  [{'drugadministrationroute': '048', 'drugchara...
# 11998  [{'drugadministrationroute': '048', 'drugchara...
# 11999  [{'medicinalproduct': 'LEVITRA', 'drugadminist...
#
#       patient.patientdeath.patientdeathdate patient.patientonsetage  \
# 0                                       NaN                     NaN
# 1                                       NaN                     NaN
# 2                                  20040322                      66
# 3                                       NaN                      61
# 4                                       NaN                      77
# 5                                       NaN                      67
# 6                                       NaN                      16
# 7                                       NaN                      47
# 8                                       NaN                     NaN
# 9                                       NaN                      73
# 10                                      NaN                     NaN
# 11                                      NaN                     NaN
# 12                                      NaN                     NaN
# 13                                      NaN                      52
# 14                                      NaN                      56
# 15                                 20040129                      57
# 16                                      NaN                     NaN
# 17                                      NaN                      66
# 18                                      NaN                      68
# 19                                      NaN                      26
# 20                                      NaN                      70
# 21                                      NaN                     NaN
# 22                                      NaN                     NaN
# 23                                      NaN                     NaN
# 24                                      NaN                     NaN
# 25                                      NaN                     NaN
# 26                                      NaN                     NaN
# 27                                      NaN                     NaN
# 28                                      NaN                     NaN
# 29                                      NaN                     NaN
# ...                                     ...                     ...
# 11970                                   NaN                     NaN
# 11971                                   NaN                      54
# 11972                                   NaN                      90
# 11973                                   NaN                      91
# 11974                              20001026                       4
# 11975                                   NaN                      69
# 11976                                   NaN                      77
# 11977                                   NaN                      40
# 11978                                   NaN                      61
# 11979                                   NaN                      78
# 11980                                   NaN                     NaN
# 11981                                   NaN                     NaN
# 11982                                   NaN                     NaN
# 11983                                   NaN                     NaN
# 11984                                   NaN                      17
# 11985                                   NaN                     NaN
# 11986                                   NaN                      11
# 11987                                   NaN                     NaN
# 11988                                   NaN                     NaN
# 11989                                   NaN                     NaN
# 11990                                   NaN                      40
# 11991                                   NaN                      21
# 11992                                   NaN                      71
# 11993                                   NaN                     NaN
# 11994                                   NaN                      65
# 11995                                   NaN                      33
# 11996                                   NaN                      62
# 11997                                   NaN                     NaN
# 11998                                   NaN                     NaN
# 11999                                   NaN                     NaN
#
#       patient.patientsex patient.patientweight  \
# 0                    NaN                   NaN
# 1                      2                   NaN
# 2                      1               78.9259
# 3                      2               49.4421
# 4                      2                   NaN
# 5                      2               74.8435
# 6                      2                   NaN
# 7                      1                   NaN
# 8                      2                   NaN
# 9                      2                   NaN
# 10                     2                  69.9
# 11                   NaN                   NaN
# 12                     1                 102.4
# 13                     2                   NaN
# 14                     1               75.7507
# 15                     1                   NaN
# 16                     2                   NaN
# 17                     1               72.5755
# 18                     2                   NaN
# 19                     2                   NaN
# 20                     1                   NaN
# 21                     1                   NaN
# 22                     2                   NaN
# 23                     2                   NaN
# 24                   NaN                   NaN
# 25                     1                   NaN
# 26                   NaN                   NaN
# 27                   NaN                   NaN
# 28                     1                   NaN
# 29                     2                   NaN
# ...                  ...                   ...
# 11970                  1                   NaN
# 11971                  2                   104
# 11972                  2                   NaN
# 11973                  2                   NaN
# 11974                  2                    15
# 11975                  2                    68
# 11976                  1                   NaN
# 11977                  1               99.7913
# 11978                  1                   NaN
# 11979                  2                   NaN
# 11980                  2                   NaN
# 11981                  2                   NaN
# 11982                  2                   NaN
# 11983                  2                   NaN
# 11984                  2                   NaN
# 11985                NaN                   NaN
# 11986                  2                   NaN
# 11987                  2                   NaN
# 11988                  2                   NaN
# 11989                  2                   NaN
# 11990                  2                   NaN
# 11991                  1                   NaN
# 11992                  1                   NaN
# 11993                  2                   NaN
# 11994                  2                   NaN
# 11995                  2                 99.97
# 11996                  2                  79.4
# 11997                NaN                   NaN
# 11998                NaN                   NaN
# 11999                  1                   NaN
#
#                                         patient.reaction  \
# 0                        [{'reactionmeddrapt': 'DEATH'}]
# 1      [{'reactionmeddrapt': 'ABORTION SPONTANEOUS'},...
# 2      [{'reactionmeddrapt': 'INTERSTITIAL LUNG DISEA...
# 3      [{'reactionmeddrapt': 'ABDOMINAL DISTENSION'},...
# 4                      [{'reactionmeddrapt': 'ANAEMIA'}]
# 5      [{'reactionmeddrapt': 'CHILLS'}, {'reactionmed...
# 6                   [{'reactionmeddrapt': 'CONVULSION'}]
# 7               [{'reactionmeddrapt': 'HYPERGLYCAEMIA'}]
# 8      [{'reactionmeddrapt': 'METASTASES TO CENTRAL N...
# 9      [{'reactionmeddrapt': 'GINGIVAL BLEEDING'}, {'...
# 10     [{'reactionmeddrapt': 'CHILLS'}, {'reactionmed...
# 11                       [{'reactionmeddrapt': 'DEATH'}]
# 12     [{'reactionmeddrapt': 'RENAL FAILURE ACUTE'}, ...
# 13     [{'reactionmeddrapt': 'CONDITION AGGRAVATED'},...
# 14     [{'reactionmeddrapt': 'INTERSTITIAL LUNG DISEA...
# 15                       [{'reactionmeddrapt': 'DEATH'}]
# 16                 [{'reactionmeddrapt': 'HAEMORRHAGE'}]
# 17     [{'reactionmeddrapt': 'BLOOD CHOLESTEROL INCRE...
# 18     [{'reactionmeddrapt': 'PHOTOSENSITIVITY REACTI...
# 19     [{'reactionmeddrapt': 'DEPRESSED LEVEL OF CONS...
# 20     [{'reactionmeddrapt': 'VENTRICULAR EXTRASYSTOL...
# 21     [{'reactionmeddrapt': 'CORONARY ARTERY DISEASE'}]
# 22                    [{'reactionmeddrapt': 'ALOPECIA'}]
# 23               [{'reactionmeddrapt': 'HAEMATOCHEZIA'}]
# 24                       [{'reactionmeddrapt': 'DEATH'}]
# 25                        [{'reactionmeddrapt': 'RASH'}]
# 26     [{'reactionmeddrapt': 'HYPERSENSITIVITY'}, {'r...
# 27              [{'reactionmeddrapt': 'PREMATURE BABY'}]
# 28        [{'reactionmeddrapt': 'ERECTILE DYSFUNCTION'}]
# 29     [{'reactionmeddrapt': 'DRUG EXPOSURE DURING PR...
# ...                                                  ...
# 11970     [{'reactionmeddrapt': 'ERECTILE DYSFUNCTION'}]
# 11971  [{'reactionmeddrapt': 'CHEST PAIN'}, {'reactio...
# 11972  [{'reactionmeddrapt': 'AGEUSIA'}, {'reactionme...
# 11973  [{'reactionmeddrapt': 'DRUG INTERACTION'}, {'r...
# 11974  [{'reactionmeddrapt': 'BONE MARROW DEPRESSION'...
# 11975  [{'reactionmeddrapt': 'BLOOD GLUCOSE INCREASED'}]
# 11976  [{'reactionmeddrapt': 'CARDIAC FAILURE CONGEST...
# 11977  [{'reactionmeddrapt': 'DIFFICULTY IN WALKING'}...
# 11978  [{'reactionmeddrapt': 'CHEST PAIN'}, {'reactio...
# 11979  [{'reactionmeddrapt': 'TRANSIENT ISCHAEMIC ATT...
# 11980  [{'reactionmeddrapt': 'DIARRHOEA'}, {'reaction...
# 11981  [{'reactionmeddrapt': 'DRUG WITHDRAWAL SYNDROM...
# 11982  [{'reactionmeddrapt': 'GRAND MAL CONVULSION'},...
# 11983  [{'reactionmeddrapt': 'DRUG WITHDRAWAL SYNDROM...
# 11984             [{'reactionmeddrapt': 'NIGHT SWEATS'}]
# 11985  [{'reactionmeddrapt': 'DIARRHOEA'}, {'reaction...
# 11986            [{'reactionmeddrapt': 'HAIR PLUCKING'}]
# 11987  [{'reactionmeddrapt': 'ANORGASMIA'}, {'reactio...
# 11988  [{'reactionmeddrapt': 'AGGRESSION'}, {'reactio...
# 11989  [{'reactionmeddrapt': 'CONFUSIONAL STATE'}, {'...
# 11990  [{'reactionmeddrapt': 'DEPRESSION'}, {'reactio...
# 11991  [{'reactionmeddrapt': 'HEPATIC FUNCTION ABNORM...
# 11992  [{'reactionmeddrapt': 'CARDIAC FIBRILLATION'},...
# 11993  [{'reactionmeddrapt': 'INJECTION SITE EXTRAVAS...
# 11994  [{'reactionmeddrapt': 'CRUSH INJURY'}, {'react...
# 11995  [{'reactionmeddrapt': 'AMENORRHOEA'}, {'reacti...
# 11996  [{'reactionmeddrapt': 'BLOOD PRESSURE ABNORMAL...
# 11997              [{'reactionmeddrapt': 'CHROMATURIA'}]
# 11998               [{'reactionmeddrapt': 'ARTHRALGIA'}]
# 11999  [{'reactionmeddrapt': 'ABDOMINAL PAIN UPPER'},...
#
#       primarysource.qualification primarysource.reportercountry receivedate  \
# 0                             NaN                       AUSTRIA    20101115
# 1                               3                UNITED KINGDOM    20090803
# 2                               1                 UNITED STATES    20061213
# 3                             NaN                 UNITED STATES    20061213
# 4                               1                 UNITED STATES    20061213
# 5                             NaN                 UNITED STATES    20061213
# 6                               1                 UNITED STATES    20061213
# 7                               3                 UNITED STATES    20061213
# 8                             NaN                 UNITED STATES    20061213
# 9                               3                 UNITED STATES    20061213
# 10                              5                 UNITED STATES    20060721
# 11                            NaN                           NaN    20061106
# 12                            NaN                           NaN    20060223
# 13                              5                 UNITED STATES    20060113
# 14                              1                 UNITED STATES    20061213
# 15                              1                         JAPAN    20080331
# 16                              5                 UNITED STATES    20071001
# 17                              3                 UNITED STATES    20061212
# 18                            NaN                 UNITED STATES    20061213
# 19                            NaN                 UNITED STATES    20061213
# 20                              3                         JAPAN    20120529
# 21                              3                 UNITED STATES    20111207
# 22                              5                 UNITED STATES    20080918
# 23                              5                 UNITED STATES    20071001
# 24                              1                 UNITED STATES    20101209
# 25                              5                 UNITED STATES    20100729
# 26                              3                 UNITED STATES    20100731
# 27                              1                        GREECE    20100811
# 28                              1                 UNITED STATES    20090304
# 29                              1                         JAPAN    20090908
# ...                           ...                           ...         ...
# 11970                           5                           NaN    20040302
# 11971                           1                           NaN    20040218
# 11972                           5                           NaN    20040209
# 11973                           3                           NaN    20040210
# 11974                           1                           NaN    20040304
# 11975                           1                           NaN    20040212
# 11976                           1                           NaN    20040205
# 11977                         NaN                           NaN    20040212
# 11978                           2                           NaN    20040219
# 11979                           3                           NaN    20040223
# 11980                           5                           NaN    20040809
# 11981                           5                           NaN    20040809
# 11982                           1                           NaN    20040809
# 11983                           5                           NaN    20040809
# 11984                           5                           NaN    20040809
# 11985                           5                           NaN    20040809
# 11986                           5                           NaN    20040809
# 11987                           5                           NaN    20040809
# 11988                           4                           NaN    20040809
# 11989                           4                           NaN    20040809
# 11990                           5                           NaN    20040630
# 11991                           1                           NaN    20040401
# 11992                           1                           NaN    20040402
# 11993                           2                           NaN    20040406
# 11994                           1                           NaN    20040405
# 11995                         NaN                           NaN    20040429
# 11996                           5                           NaN    20040503
# 11997                           5                           NaN    20040602
# 11998                           5                           NaN    20040603
# 11999                         NaN                           NaN    20040602
#
#       serious seriousnesscongenitalanomali seriousnessdeath  \
# 0           1                          NaN                1
# 1           1                          NaN              NaN
# 2           1                          NaN                1
# 3           1                          NaN              NaN
# 4           1                          NaN              NaN
# 5           1                          NaN              NaN
# 6           1                          NaN              NaN
# 7           1                          NaN              NaN
# 8           2                          NaN              NaN
# 9           1                          NaN              NaN
# 10          2                          NaN              NaN
# 11          1                          NaN                1
# 12          1                          NaN              NaN
# 13          1                          NaN              NaN
# 14          1                          NaN              NaN
# 15          1                          NaN                1
# 16          1                          NaN              NaN
# 17          2                          NaN              NaN
# 18          1                          NaN              NaN
# 19          2                          NaN              NaN
# 20          1                          NaN              NaN
# 21          1                          NaN              NaN
# 22          2                          NaN              NaN
# 23          1                          NaN              NaN
# 24          1                          NaN                1
# 25          2                          NaN              NaN
# 26          2                          NaN              NaN
# 27          1                          NaN                1
# 28          2                          NaN              NaN
# 29          2                          NaN              NaN
# ...       ...                          ...              ...
# 11970       2                          NaN              NaN
# 11971       1                          NaN              NaN
# 11972       1                          NaN              NaN
# 11973       1                          NaN              NaN
# 11974       1                          NaN                1
# 11975       1                          NaN              NaN
# 11976       1                          NaN              NaN
# 11977       1                          NaN              NaN
# 11978       1                          NaN              NaN
# 11979       1                          NaN              NaN
# 11980       2                          NaN              NaN
# 11981       2                          NaN              NaN
# 11982       1                          NaN              NaN
# 11983       2                          NaN              NaN
# 11984       2                          NaN              NaN
# 11985       2                          NaN              NaN
# 11986       2                          NaN              NaN
# 11987       2                          NaN              NaN
# 11988       2                          NaN              NaN
# 11989       2                          NaN              NaN
# 11990       1                          NaN              NaN
# 11991       1                          NaN              NaN
# 11992       1                          NaN              NaN
# 11993       2                          NaN              NaN
# 11994       1                          NaN              NaN
# 11995       2                          NaN              NaN
# 11996       1                          NaN              NaN
# 11997       2                          NaN              NaN
# 11998       2                          NaN              NaN
# 11999       2                          NaN              NaN
#
#       seriousnessdisabling seriousnesshospitalization  \
# 0                      NaN                        NaN
# 1                      NaN                        NaN
# 2                      NaN                        NaN
# 3                      NaN                        NaN
# 4                      NaN                        NaN
# 5                      NaN                        NaN
# 6                      NaN                          1
# 7                      NaN                          1
# 8                      NaN                        NaN
# 9                      NaN                        NaN
# 10                     NaN                        NaN
# 11                     NaN                        NaN
# 12                     NaN                        NaN
# 13                     NaN                        NaN
# 14                     NaN                          1
# 15                     NaN                        NaN
# 16                     NaN                        NaN
# 17                     NaN                        NaN
# 18                     NaN                        NaN
# 19                     NaN                        NaN
# 20                     NaN                        NaN
# 21                     NaN                        NaN
# 22                     NaN                        NaN
# 23                     NaN                        NaN
# 24                     NaN                        NaN
# 25                     NaN                        NaN
# 26                     NaN                        NaN
# 27                     NaN                        NaN
# 28                     NaN                        NaN
# 29                     NaN                        NaN
# ...                    ...                        ...
# 11970                  NaN                        NaN
# 11971                  NaN                          1
# 11972                  NaN                        NaN
# 11973                  NaN                          1
# 11974                  NaN                          1
# 11975                  NaN                        NaN
# 11976                  NaN                        NaN
# 11977                  NaN                        NaN
# 11978                  NaN                          1
# 11979                  NaN                        NaN
# 11980                  NaN                        NaN
# 11981                  NaN                        NaN
# 11982                  NaN                        NaN
# 11983                  NaN                        NaN
# 11984                  NaN                        NaN
# 11985                  NaN                        NaN
# 11986                  NaN                        NaN
# 11987                  NaN                        NaN
# 11988                  NaN                        NaN
# 11989                  NaN                        NaN
# 11990                  NaN                        NaN
# 11991                    1                          1
# 11992                  NaN                          1
# 11993                  NaN                        NaN
# 11994                  NaN                        NaN
# 11995                  NaN                        NaN
# 11996                  NaN                        NaN
# 11997                  NaN                        NaN
# 11998                  NaN                        NaN
# 11999                  NaN                        NaN
#
#       seriousnesslifethreatening seriousnessother transmissiondate
# 0                            NaN              NaN         20110411
# 1                            NaN                1         20100115
# 2                            NaN              NaN         20070707
# 3                            NaN                1         20070707
# 4                            NaN                1         20070707
# 5                            NaN                1         20070707
# 6                            NaN              NaN         20070707
# 7                            NaN              NaN         20070707
# 8                            NaN              NaN         20070707
# 9                            NaN                1         20070707
# 10                           NaN              NaN         20061208
# 11                           NaN              NaN         20070319
# 12                           NaN                1         20060701
# 13                           NaN                1         20060701
# 14                           NaN              NaN         20070707
# 15                           NaN              NaN         20080703
# 16                           NaN                1         20080405
# 17                           NaN              NaN         20070707
# 18                           NaN                1         20070707
# 19                           NaN              NaN         20070707
# 20                           NaN                1         20120825
# 21                           NaN                1         20120403
# 22                           NaN              NaN         20090109
# 23                           NaN                1         20080405
# 24                           NaN              NaN         20110411
# 25                           NaN              NaN         20110219
# 26                           NaN              NaN         20110219
# 27                           NaN              NaN         20110219
# 28                           NaN              NaN         20090719
# 29                           NaN              NaN         20100115
# ...                          ...              ...              ...
# 11970                        NaN              NaN         20041129
# 11971                        NaN              NaN         20041129
# 11972                        NaN                1         20041129
# 11973                        NaN                1         20041129
# 11974                        NaN              NaN         20041129
# 11975                        NaN                1         20041129
# 11976                        NaN                1         20041129
# 11977                          1              NaN         20041129
# 11978                        NaN              NaN         20041129
# 11979                        NaN                1         20041129
# 11980                        NaN              NaN         20050211
# 11981                        NaN              NaN         20050211
# 11982                        NaN                1         20050211
# 11983                        NaN              NaN         20050211
# 11984                        NaN              NaN         20050211
# 11985                        NaN              NaN         20050211
# 11986                        NaN              NaN         20050211
# 11987                        NaN              NaN         20050211
# 11988                        NaN              NaN         20050211
# 11989                        NaN              NaN         20050211
# 11990                          1                1         20050107
# 11991                        NaN              NaN         20050107
# 11992                        NaN              NaN         20050107
# 11993                        NaN              NaN         20050107
# 11994                        NaN                1         20050107
# 11995                        NaN              NaN         20050107
# 11996                        NaN                1         20050107
# 11997                        NaN              NaN         20050107
# 11998                        NaN              NaN         20050107
# 11999                        NaN              NaN         20050107
#
# [12000 rows x 17 columns]

# %%
# it can be seen that patient.drug and patient.reaction need to be expanded
# create two new data frames for each attribute filter/reduce then merge with original 

# create a new reaction dataframe
data = []
for row in range(len(df['patient.reaction'])):
    reactions = []
    for list_index in range(len(df['patient.reaction'][row])):
        reactions.append(df['patient.reaction'][row][list_index]['reactionmeddrapt'])
    data.append(reactions)
reaction = pd.DataFrame(data)

# create a new drug dataframe 
data = []
for row in range(len(df['patient.drug'])):
    drugs = []
    for list_index in range(len(df['patient.drug'][row])):
        drugs.append(df['patient.drug'][row][list_index]['medicinalproduct'])
    data.append(drugs)
drug = pd.DataFrame(data)

# give columns appropriate names  
for column in reaction.columns:
    reaction = reaction.rename(columns = {column : 'reaction_' + str(column)})
    
for column in drug.columns:
    drug = drug.rename(columns = {column : 'drug_' + str(column)})

# %%
# Now drop the nested columns and merge with new dataframes
df = df.drop(columns = ['patient.drug','patient.reaction'])

patient_info = pd.concat([df, drug, reaction], axis=1, join='inner')

# delete previous dataframes to free memory 
lst = [df, drug, reaction]
del [lst]
gc.collect()

#some more column filtering
patient_info = patient_info[['patient.patientonsetage',	'patient.patientsex','patient.patientweight', 
                             'primarysource.reportercountry','serious','transmissiondate', 
                             'receivedate','drug_0', 'reaction_0', 'reaction_1', 'reaction_2']]

# %%
# check column datatypes
patient_info.dtypes
# Out:
# patient.patientonsetage          object
# patient.patientsex               object
# patient.patientweight            object
# primarysource.reportercountry    object
# serious                          object
# transmissiondate                 object
# receivedate                      object
# drug_0                           object
# reaction_0                       object
# reaction_1                       object
# reaction_2                       object
# dtype: object

# %%
# convert age and weight 
patient_info['patient.patientonsetage'] = pd.to_numeric(df['patient.patientonsetage'])
patient_info['patient.patientweight'] = pd.to_numeric(df['patient.patientweight'])
patient_info['patient.patientsex'] = pd.to_numeric(df['patient.patientsex'])
# convert all other attributes to the appropriate data type
patient_info['primarysource.reportercountry'] = patient_info['primarysource.reportercountry'].astype(str)
patient_info['serious'] = patient_info['serious'].astype(int)
patient_info['transmissiondate'] = patient_info['transmissiondate'].astype(int)
patient_info['receivedate'] = patient_info['receivedate'].astype(int)
patient_info['drug_0'] = patient_info['drug_0'].astype(str)
patient_info['reaction_0'] = patient_info['reaction_0'].astype(str)
patient_info['reaction_1'] = patient_info['reaction_1'].astype(str)
patient_info['reaction_2'] = patient_info['reaction_2'].astype(str)

# Now eliminate outliers on age and weight
age_q1 = patient_info['patient.patientonsetage'].quantile(0.25)
age_q3 = patient_info['patient.patientonsetage'].quantile(0.75)
age_IQR = age_q3 - age_q1
weight_q1 = patient_info['patient.patientweight'].quantile(0.25)
weight_q3 = patient_info['patient.patientweight'].quantile(0.75)
weight_IQR = weight_q3 - weight_q1
age_upperbound = age_q3 + 1.5*age_IQR
age_lowerbound = age_q1 - 1.5*age_IQR
weight_upperbound = weight_q3 + 1.5*weight_IQR
weight_lowerbound = weight_q3 - 1.5*weight_IQR
patient_info = patient_info.drop(
    patient_info[patient_info['patient.patientonsetage'] < age_lowerbound].index)
patient_info = patient_info.drop(
    patient_info[patient_info['patient.patientonsetage'] > age_upperbound].index)
patient_info = patient_info.drop(
    patient_info[patient_info['patient.patientweight'] < weight_lowerbound].index)
patient_info = patient_info.drop(
    patient_info[patient_info['patient.patientweight'] > weight_upperbound].index)

# %%
# convert weight in kilograms to weight in pounds
patient_info['patient.patientweight'] = patient_info['patient.patientweight'] * 2.205

# %%
# drop all rows with null patient demographic info 
patient_info = patient_info.dropna(subset=['patient.patientonsetage', 'patient.patientsex',
                                                                             'patient.patientweight',])
# drop rows with patientsex = 0, rename 
patient_info = patient_info[patient_info['patient.patientsex'] != 0]
patient_info.loc[(patient_info['patient.patientsex'] == 1), 'patient.patientsex'] = 'male'
patient_info.loc[(patient_info['patient.patientsex'] == 2), 'patient.patientsex'] = 'female'

# make sure we will still have millions of data points  
patient_info.count()
# Out:
# patient.patientonsetage          2463
# patient.patientsex               2463
# patient.patientweight            2463
# primarysource.reportercountry    2463
# serious                          2463
# transmissiondate                 2463
# receivedate                      2463
# drug_0                           2463
# reaction_0                       2463
# reaction_1                       2463
# reaction_2                       2463
# dtype: int64

# %%
# reset indexing from 0 through number of data objects
patient_info = patient_info.reset_index(drop = True)

# %%
# Preview of the data
patient_info.head()
# Out:
#    patient.patientonsetage patient.patientsex  patient.patientweight  \
# 0                     66.0               male             174.031610
# 1                     61.0             female             109.019831
# 2                     67.0             female             165.029918
# 3                     56.0               male             167.030293
# 4                     66.0               male             160.028978
#
#   primarysource.reportercountry  serious  transmissiondate  receivedate  \
# 0                 UNITED STATES        1          20070707     20061213
# 1                 UNITED STATES        1          20070707     20061213
# 2                 UNITED STATES        1          20070707     20061213
# 3                 UNITED STATES        1          20070707     20061213
# 4                 UNITED STATES        2          20070707     20061212
#
#     drug_0                   reaction_0                reaction_1   reaction_2
# 0   IRESSA    INTERSTITIAL LUNG DISEASE                      None         None
# 1   IRESSA         ABDOMINAL DISTENSION  BLOOD PRESSURE DECREASED  CANDIDIASIS
# 2   IRESSA                       CHILLS                  DYSPNOEA      FATIGUE
# 3   IRESSA    INTERSTITIAL LUNG DISEASE                      None         None
# 4  CASODEX  BLOOD CHOLESTEROL INCREASED                      None         None

# %%
# check to see if patient demographic info is normally distributed or skewed
patient_info.hist(column = 'patient.patientonsetage', bins = 6);

# %%
# verify with qq plot
stats.probplot(patient_info['patient.patientonsetage'], dist = 'norm', plot = plt,);

# %%
patient_info.hist(column = 'patient.patientweight', bins = 6);

# %%
stats.probplot(patient_info['patient.patientweight'], dist = 'norm', plot = plt,);

# measure skew
weight_skew = stats.skew(patient_info['patient.patientweight'])
weight_skew

# test skew
stats.skewtest(patient_info['patient.patientweight'])
# Out:
# SkewtestResult(statistic=11.76618172479939, pvalue=5.830418590930159e-32)

# %%
# Plot bar chart of percentage of male vs female, male = 1, female = 2
patient_info['patient.patientsex'].value_counts(1).plot(kind = 'bar', title = 'patient.patientsex');

# %%
# Weight looks slightley right skewed, make box plot for comparison
boxplot = patient_info.boxplot(column=['patient.patientonsetage', 'patient.patientweight']);
